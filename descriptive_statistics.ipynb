# %% [markdown]
# # Descriptive Data Analysis

# %% [markdown]
# In the following notebook, a brief Descriptive analysis of th e data set has been done.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Use your own local path please!
path = "./Data/"
file_name = ["train.csv", "test.csv", "submission.csv"]
df_train = pd.read_csv(path + file_name[0])

#Check the Note in Data Preprocessing notebook to see why we commented out below!

# df_test = pd.read_csv(path + file_name[1])
# df_submission = pd.read_csv(path + file_name[2])

# %% [markdown]
# ## Attributes:
# Below you can find the list of attributes in the data. The class is the attribute that we want to infer in our analysis and it corresponds to the music genre.

# %%
list(df_train.columns)
# Out:
# ['Artist Name',
#  'Track Name',
#  'Popularity',
#  'danceability',
#  'energy',
#  'key',
#  'loudness',
#  'mode',
#  'speechiness',
#  'acousticness',
#  'instrumentalness',
#  'liveness',
#  'valence',
#  'tempo',
#  'duration_in min/ms',
#  'time_signature',
#  'Class']

# %% [markdown]
# ## General Analysis of data

# %%
df_train
# Out:
#                  Artist Name                             Track Name
# 0                 Bruno Mars  That's What I Like (feat. Gucci Mane)  \
# 1                     Boston                           Hitch a Ride
# 2              The Raincoats                     No Side to Fall In
# 3                       Deno             Lingo (feat. J.I & Chunkz)
# 4      Red Hot Chili Peppers      Nobody Weird Like Me - Remastered
# ...                      ...                                    ...
# 17991            Green-House                              Find Home
# 17992               Micatone                               All Gone
# 17993        Smash Hit Combo                           Peine perdue
# 17994                Beherit                         Salomon's Gate
# 17995         The Raconteurs                     Broken Boy Soldier
#
#        Popularity  danceability  energy   key  loudness  mode  speechiness
# ...

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17996 entries, 0 to 17995
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Artist Name         17996 non-null  object
#  1   Track Name          17996 non-null  object
#  2   Popularity          17568 non-null  float64
#  3   danceability        17996 non-null  float64
#  4   energy              17996 non-null  float64
#  5   key                 15982 non-null  float64
#  6   loudness            17996 non-null  float64
#  7   mode                17996 non-null  int64
#  8   speechiness         17996 non-null  float64
#  9   acousticness        17996 non-null  float64
#  10  instrumentalness    13619 non-null  float64
#  11  liveness            17996 non-null  float64
#  12  valence             17996 non-null  float64
#  13  tempo               17996 non-null  float64
#  14  duration_in min/ms  17996 non-null  float64
# ...

# %% [markdown]
# ## Some Basic Statistical analysis

# %%
df_train.describe()
# Out:
#          Popularity  danceability        energy           key      loudness
# count  17568.000000  17996.000000  17996.000000  15982.000000  17996.000000  \
# mean      44.512124      0.543433      0.662777      5.952447     -7.910660
# std       17.426928      0.166268      0.235373      3.196854      4.049151
# min        1.000000      0.059600      0.000020      1.000000    -39.952000
# 25%       33.000000      0.432000      0.509000      3.000000     -9.538000
# 50%       44.000000      0.545000      0.700000      6.000000     -7.016000
# 75%       56.000000      0.659000      0.860000      9.000000     -5.189000
# max      100.000000      0.989000      1.000000     11.000000      1.355000
#
#                mode   speechiness  acousticness  instrumentalness
# count  17996.000000  17996.000000  17996.000000      13619.000000  \
# mean       0.636753      0.079707      0.247082          0.177562
# std        0.480949      0.083576      0.310632          0.304048
# ...

# %% [markdown]
# Artist Names and the count of tracks present in the data from each of them

# %%
df_train.groupby('Artist Name').count()[['Track Name']].sort_values('Track Name', ascending = False)
# Out:
#                                             Track Name
# Artist Name
# Backstreet Boys                                     69
# Westlife                                            60
# Britney Spears                                      54
# Eyal Golan                                          48
# Omer Adam                                           48
# ...                                                ...
# Jax                                                  1
# Javi That's Me                                       1
# Javed-Mohsin, Arijit Singh, Shreya Ghoshal           1
# Javed Bashir, Junaid Bashir                          1
# נאדה                                             1
#
# [9149 rows x 1 columns]

# %% [markdown]
# ## Identifying Nan Values

# %%
df_train.isna().sum()
# Out:
# Artist Name              0
# Track Name               0
# Popularity             428
# danceability             0
# energy                   0
# key                   2014
# loudness                 0
# mode                     0
# speechiness              0
# acousticness             0
# instrumentalness      4377
# liveness                 0
# valence                  0
# tempo                    0
# duration_in min/ms       0
# time_signature           0
# Class                    0
# dtype: int64

# %% [markdown]
# ## Correlation Map

# %%
cor = df_train.iloc[:, 2:].corr()
plt.figure(figsize=(10,8))
sns.heatmap(data=cor)
plt.show()

# %% [markdown]
# ## Features Distribution

# %%
df_train.hist(figsize=(15,15))
plt.show()

# %% [markdown]
# ## Distribution of data over different classes in our target variable "Genre"

# %%
df_train.Class.value_counts()[df_train.Class.unique()].plot(kind='bar',title='Distribution of genre values across classes')
plt.show()
