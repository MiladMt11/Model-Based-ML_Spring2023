# %% [markdown]
# # Preprocessing

# %% [markdown]
# In the following notebook the preprocessing is done. We handled the Nan values with the mean value in the problematic columns, drop unwanted columns and then save the data frame as a pickle file to be used in the other notebooks for the experiments.
#
# **NOTE:** Since we have enough data in the train.csv, we only use this part of the downloaded dataset for our use in the project.

# %%
import pandas as pd
import numpy as np

# %%
#Use your own local path please!
path = "./Data/"
file_name = ["train.csv", "test.csv", "submission.csv"]

df_train = pd.read_csv(path + file_name[0])

# df_test = pd.read_csv(path + file_name[1])
# df_submission = pd.read_csv(path + file_name[2])


#Fill the Nan Values with mean.
df_train['key'] = df_train['key'].fillna(df_train['key'].mean())

df_train['instrumentalness'] = df_train['instrumentalness'].fillna(df_train['instrumentalness'].mean())

df_train['Popularity'] = df_train['Popularity'].fillna(df_train['Popularity'].mean())

#Drop two columns that we won\t use in our project
df = df_train.drop(['Artist Name','Track Name'],axis=1).copy()

df
# Out:
#        Popularity  danceability  energy   key  loudness  mode  speechiness  \
# 0            60.0         0.854   0.564   1.0    -4.964     1       0.0485
# 1            54.0         0.382   0.814   3.0    -7.230     1       0.0406
# 2            35.0         0.434   0.614   6.0    -8.334     1       0.0525
# 3            66.0         0.853   0.597  10.0    -6.528     0       0.0555
# 4            53.0         0.167   0.975   2.0    -4.279     1       0.2160
# ...           ...           ...     ...   ...       ...   ...          ...
# 17991        35.0         0.166   0.109   7.0   -17.100     0       0.0413
# 17992        27.0         0.638   0.223  11.0   -10.174     0       0.0329
# 17993        34.0         0.558   0.981   4.0    -4.683     0       0.0712
# 17994        29.0         0.215   0.805   6.0   -12.757     0       0.1340
# 17995        43.0         0.400   0.853   4.0    -5.320     0       0.0591
#
#        acousticness  instrumentalness  liveness  valence    tempo  \
# ...

# %%
# Saving the pickle file
df.to_pickle('pickle/df.pkl')
